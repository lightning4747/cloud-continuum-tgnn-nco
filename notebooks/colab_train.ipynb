# %% [markdown]
# # Dynamic CNF Placement via TGNN + NCO — Google Colab High-Throughput Driver
#
# This notebook handles repository setup, GPU device verification, and high-throughput PPO training execution (utilizing ~12–14 GB VRAM on 15 GB GPUs).

# %% [markdown]
# ## 1. Mount Google Drive & Navigate to Workspace

# %%
from google.colab import drive
drive.mount('/content/drive')

# Set repository workspace directory
# %cd /content/drive/MyDrive/cloud-continuum-tgnn-nco

# %% [markdown]
# ## 2. Install Dependencies & Local Package

# %%
# !pip install -r requirements.txt
# !pip install -e .

# %% [markdown]
# ## 3. Verify PyTorch & GPU Acceleration

# %%
import torch
print("PyTorch Version:", torch.__version__)
print("CUDA Available :", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU Device Name:", torch.cuda.get_device_name(0))
    print("VRAM Capacity  :", f"{torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")

# %% [markdown]
# ## 4. Run High-Throughput TGNN-NCO PPO Training (~12-14 GB VRAM Utilization)

# %%
# !python scripts/train.py --num-envs 16 --batch-size 512 --d-model 256 --n-steps 2048 --device cuda --max-steps 2000000
